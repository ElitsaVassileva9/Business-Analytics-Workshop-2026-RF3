# %%
import pandas as pd
holidays_only_df =pd.read_csv("holidays_only_df.csv",sep=",")
holidays_only_df.head()
# Out:
#          date logistieke location id crop_type fpc_index  trolleys  \
# 0  2021-01-25               Aalsmeer        BL     fpc_1       208
# 1  2021-01-26               Aalsmeer        BL     fpc_1       132
# 2  2021-01-27               Aalsmeer        BL     fpc_1       131
# 3  2021-01-28               Aalsmeer        BL     fpc_1        88
# 4  2021-01-29               Aalsmeer        BL     fpc_1       162
#
#    3_avg_price_per_item_lag_1  3_avg_revenue_per_transaction_lag_1  \
# 0                        0.27                               157.08
# 1                        0.24                               113.72
# 2                        0.25                               166.52
# 3                        0.24                               228.31
# 4                        0.24                               149.73
#
#    3_items_sold_cv_lag_1  3_items_sold_mean_lag_1  3_items_sold_std_lag_1  \
# 0                   1.26                   6146.0                 7772.52
# ...

# %%
len(holidays_only_df)
# Out:
# 14793

# %%
import pandas as pd

test_holidays_only =pd.read_csv("holidays_2024_df.csv",sep=",")
test_holidays_only.head()
# Out:
#          date logistieke location id crop_type fpc_index  trolleys  \
# 0  2024-01-02               Aalsmeer        BL     fpc_1       353
# 1  2024-01-24               Aalsmeer        BL     fpc_1       149
# 2  2024-01-25               Aalsmeer        BL     fpc_1       114
# 3  2024-01-26               Aalsmeer        BL     fpc_1       196
# 4  2024-01-29               Aalsmeer        BL     fpc_1       268
#
#    3_avg_price_per_item_lag_1  3_avg_revenue_per_transaction_lag_1  \
# 0                        0.31                               297.50
# 1                        0.31                               156.96
# 2                        0.35                               153.44
# 3                        0.28                               194.77
# 4                        0.33                                99.27
#
#    3_items_sold_cv_lag_1  3_items_sold_mean_lag_1  3_items_sold_std_lag_1  \
# 0                   0.00                   3800.0                    0.00
# ...

# %%
len(test_holidays_only)
# Out:
# 3265

# %%
train_holidays_only =pd.read_csv("holidays_till_2023_df.csv",sep=",")
train_holidays_only.head()
# Out:
#          date logistieke location id crop_type fpc_index  trolleys  \
# 0  2021-01-25               Aalsmeer        BL     fpc_1       208
# 1  2021-01-26               Aalsmeer        BL     fpc_1       132
# 2  2021-01-27               Aalsmeer        BL     fpc_1       131
# 3  2021-01-28               Aalsmeer        BL     fpc_1        88
# 4  2021-01-29               Aalsmeer        BL     fpc_1       162
#
#    3_avg_price_per_item_lag_1  3_avg_revenue_per_transaction_lag_1  \
# 0                        0.27                               157.08
# 1                        0.24                               113.72
# 2                        0.25                               166.52
# 3                        0.24                               228.31
# 4                        0.24                               149.73
#
#    3_items_sold_cv_lag_1  3_items_sold_mean_lag_1  3_items_sold_std_lag_1  \
# 0                   1.26                   6146.0                 7772.52
# ...

# %%
len(train_holidays_only)
# Out:
# 11528

# %%
no_holidays_df =pd.read_csv("no_holidays_df.csv",sep=",")
no_holidays_df.head()
# Out:
#          date logistieke location id crop_type fpc_index  trolleys  \
# 0  2021-01-04               Aalsmeer        BL     fpc_1       287
# 1  2021-01-05               Aalsmeer        BL     fpc_1       113
# 2  2021-01-06               Aalsmeer        BL     fpc_1        97
# 3  2021-01-07               Aalsmeer        BL     fpc_1        69
# 4  2021-01-08               Aalsmeer        BL     fpc_1       143
#
#    3_avg_price_per_item_lag_1  3_avg_revenue_per_transaction_lag_1  \
# 0                         NaN                                  NaN
# 1                        0.21                                76.74
# 2                        0.21                               156.01
# 3                        0.27                               185.41
# 4                        0.24                               247.17
#
#    3_items_sold_cv_lag_1  3_items_sold_mean_lag_1  3_items_sold_std_lag_1  \
# 0                    NaN                      NaN                     NaN
# ...

# %%
len(no_holidays_df)
# Out:
# 57287

# %%
test_no_holidays =pd.read_csv("no_holidays_2024_df.csv",sep=",")
test_no_holidays.head()
# Out:
#          date logistieke location id crop_type fpc_index  trolleys  \
# 0  2024-01-03               Aalsmeer        BL     fpc_1       170
# 1  2024-01-04               Aalsmeer        BL     fpc_1       139
# 2  2024-01-05               Aalsmeer        BL     fpc_1       213
# 3  2024-01-08               Aalsmeer        BL     fpc_1       280
# 4  2024-01-09               Aalsmeer        BL     fpc_1       140
#
#    3_avg_price_per_item_lag_1  3_avg_revenue_per_transaction_lag_1  \
# 0                        0.31                               161.80
# 1                        0.27                               166.13
# 2                        0.26                               165.61
# 3                        0.27                               101.12
# 4                        0.31                               125.17
#
#    3_items_sold_cv_lag_1  3_items_sold_mean_lag_1  3_items_sold_std_lag_1  \
# 0                   0.89                 22405.00                20032.34
# ...

# %%
len(test_no_holidays)
# Out:
# 14521

# %%
train_no_holidays =pd.read_csv("no_holidays_till_2023_df.csv",sep=",")
train_no_holidays.head()
# Out:
#          date logistieke location id crop_type fpc_index  trolleys  \
# 0  2021-01-04               Aalsmeer        BL     fpc_1       287
# 1  2021-01-05               Aalsmeer        BL     fpc_1       113
# 2  2021-01-06               Aalsmeer        BL     fpc_1        97
# 3  2021-01-07               Aalsmeer        BL     fpc_1        69
# 4  2021-01-08               Aalsmeer        BL     fpc_1       143
#
#    3_avg_price_per_item_lag_1  3_avg_revenue_per_transaction_lag_1  \
# 0                         NaN                                  NaN
# 1                        0.21                                76.74
# 2                        0.21                               156.01
# 3                        0.27                               185.41
# 4                        0.24                               247.17
#
#    3_items_sold_cv_lag_1  3_items_sold_mean_lag_1  3_items_sold_std_lag_1  \
# 0                    NaN                      NaN                     NaN
# ...

# %%
len(train_no_holidays)
# Out:
# 42766

# %%
train_holidays_only["year"].unique()
# Out:
# array([2021, 2022, 2023])

# %%
test_holidays_only["year"].unique()
# Out:
# array([2024])

# %%
train_no_holidays["year"].unique()
# Out:
# array([2021, 2022, 2023])

# %%
test_no_holidays["year"].unique()
# Out:
# array([2024])

# %%
all_dates_inclholidays = pd.concat(
    [no_holidays_df, holidays_only_df],
    axis=0,
    ignore_index=True
)

# %%
len(no_holidays_df) + len(holidays_only_df) == len(all_dates_inclholidays)
# Out:
# True

# %%
test_all_dates_inclholidays = pd.concat(
    [test_no_holidays, test_holidays_only],
    axis=0,
    ignore_index=True
)

# %%
len(test_no_holidays) + len(test_holidays_only) == len(test_all_dates_inclholidays)
# Out:
# True

# %%
train_all_dates_inclholidays = pd.concat(
    [train_no_holidays, train_holidays_only],
    axis=0,
    ignore_index=True
)

# %%
len(train_no_holidays) + len(train_holidays_only) == len(train_all_dates_inclholidays)
# Out:
# True

# %%
# Holidays-only datasets
holidays_only_df.to_csv("holidays_only_df.csv", index=False)
train_holidays_only.to_csv("train_holidays_only.csv", index=False)
test_holidays_only.to_csv("test_holidays_only.csv", index=False)

# No-holidays datasets
no_holidays_df.to_csv("no_holidays_df.csv", index=False)
train_no_holidays.to_csv("train_no_holidays.csv", index=False)
test_no_holidays.to_csv("test_no_holidays.csv", index=False)

# Holidays-only + No-holidays datasets
all_dates_inclholidays.to_csv("all_dates_inclholidays.csv", index=False)
train_all_dates_inclholidays.to_csv("train_all_dates_inclholidays.csv", index=False)
test_all_dates_inclholidays.to_csv("test_all_dates_inclholidays.csv", index=False)
